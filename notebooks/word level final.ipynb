# %%
import numpy as np
import keras
from keras import layers
import string
import random
import sys
from utils import log, generate_overlapping_sequences, load_short_jokes_corpus
# Out:
# Using TensorFlow backend.

# %%
jokes, text = load_short_jokes_corpus(limit=None)
print 'Corpus Length: {c}'.format(c=len(text))
# Out:
# Corpus Length: 21787187

# %%
import re
def clean_punctuation(joke): 
    tokens = re.findall(r"[\w']+|[.,!?;]+", joke)
    cleaned = []
    for token in tokens:
        if '?' in token:
            cleaned.append('?')
        elif '!' in token:
            cleaned.append('!')
        elif '..' in token:
            cleaned.append('...')
        else:
            cleaned.append(token)
    if '.' not in cleaned[-1] and '?' not in cleaned[-1] and '!' not in cleaned[-1]:
        cleaned.append('.')
    return " ".join(cleaned)

# %%
jokes = map(clean_punctuation, jokes)

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(filters='"#$%&()*+,-/:;<=>@[\\]^_`{|}~\t\n')
tokenizer.fit_on_texts(jokes)
vocab_size = len(tokenizer.word_index) + 1

print('Vocab Size', vocab_size)
# Out:
# ('Vocab Size', 70651)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds.astype('float64'))
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def generate_overlapping_encoded_sequences(jokes, maxlen, step):
    sentences = []
    next_words = [] # holds the targets
    for joke in jokes:
        for i in range(0, len(joke) - maxlen, step):
            sentences.append(joke[i: i + maxlen])
            next_words.append(joke[i + maxlen])
    return sentences, next_words

# %%
# split jokes into sequences of 11
integer_encoded_docs = tokenizer.texts_to_sequences(jokes)
split_encoded_docs, next_words = generate_overlapping_encoded_sequences(integer_encoded_docs, 11, 3)
padded_docs = pad_sequences(split_encoded_docs, padding='post')
# need to get next word for each of these 
next_words = np.asarray(next_words)
print("Number of Sequences:", len(padded_docs))
# Out:
# ('Number of Sequences:', 753882)

# %%
print 'Vectorization.'
y = np.zeros((len(padded_docs), vocab_size), dtype=np.bool)
for i, padded_doc in enumerate(padded_docs):
    y[i, next_words[i]] = 1
# Out:
# Vectorization.

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Bidirectional, Dropout
from keras.optimizers import RMSprop
from keras.layers.embeddings import Embedding

# %%
model = Sequential()
model.add(Embedding(vocab_size, 100, input_length=padded_docs.shape[1], mask_zero=True))
model.add(Bidirectional(LSTM(128, dropout=0.1, recurrent_dropout=0.1, return_sequences=True)))
model.add(Bidirectional(LSTM(128, dropout=0.1, recurrent_dropout=0.1, return_sequences=True)))
model.add(Bidirectional(LSTM(128)))
model.add(Dense(2048, kernel_regularizer=keras.regularizers.l2(0.001), activation='relu'))
model.add(Dense(vocab_size, activation='softmax'))
optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
print model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 11, 100)           7065100
# _________________________________________________________________
# bidirectional_11 (Bidirectio (None, 11, 256)           234496
# _________________________________________________________________
# bidirectional_12 (Bidirectio (None, 11, 256)           394240
# _________________________________________________________________
# bidirectional_13 (Bidirectio (None, 256)               394240
# _________________________________________________________________
# dense_5 (Dense)              (None, 2048)              526336
# _________________________________________________________________
# dense_6 (Dense)              (None, 70651)             144763899
# =================================================================
# Total params: 153,378,311
# Trainable params: 153,378,311
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
word_index = tokenizer.word_index
index_to_word = dict((index, word) for word, index in word_index.items())
max_words = 5
maxlen = padded_docs.shape[1]

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds.astype('float64'))
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
for i in range(1, 40):
    print 'Epoch: {i}'.format(i=i)
    model.fit(padded_docs, y, batch_size=1028, nb_epoch=1) 
    if i >= 3:
        model.save_weights('finalWeights'.format(i=i), overwrite=True)
    print '\n'
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print '\n------------ temperature: {t}'.format(t=temperature)
        start_index = random.randint(0, len(text.split(' ')) - max_words - 1)
        generated_text = " ".join(text.split(' ')[start_index: start_index + max_words])
        integer_encoded_gen_text = tokenizer.texts_to_sequences([generated_text])
        readable_gen_text = " ".join(map(lambda key: index_to_word[key], integer_encoded_gen_text[0]))
        print  '-----  Generating with Seed: "{gen}"'.format(gen=readable_gen_text)
        print '\n'
        sys.stdout.write(readable_gen_text)

        for i in range(35):
            integer_encoded_gen_text = tokenizer.texts_to_sequences([generated_text])
#             print('Integer Encoded', integer_encoded_gen_text)
            readable_gen_text = " ".join(map(lambda key: index_to_word[key], integer_encoded_gen_text[0]))
            padded_gen_text = pad_sequences(integer_encoded_gen_text, maxlen=maxlen, padding='pre')
            preds = model.predict(padded_gen_text, verbose=0)[0]

            next_index = sample(preds, temperature)
            most_probable_next_word = index_to_word[next_index]
#             print('Generated:', generated_text, 'Next: ', most_probable_next_word)
            generated_text += " " + most_probable_next_word
            generated_text = " ".join(generated_text.split(' ')[1:])
            sys.stdout.write(" " + most_probable_next_word)
            if most_probable_next_word in ('.', '?', '!'):
                break
# Out:
# Epoch: 1
# Epoch 1/1
# 753882/753882 [==============================] - 2037s - loss: 8.4357
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "call a horny herbaceous bread"
#
#
# call a horny herbaceous bread .
# ------------ temperature: 0.5
# -----  Generating with Seed: "what do you call"
#
#
# what do you call .
# ------------ temperature: 1.0
# -----  Generating with Seed: "he was charged with shooting"
#
#
# he was charged with shooting .
# ------------ temperature: 1.2
# -----  Generating with Seed: "bleach i swear if i"
#
#
# bleach i swear if i fast hammer greens' blood five time saying paper qt3 funerals lidocaine shelf jesus americas blame screaming one hey ten once road's 17 him ask been science accepted i nullpointerexception screams heee .Epoch: 2
# Epoch 1/1
# 753882/753882 [==============================] - 2347s - loss: 6.8633
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "manchester united lost because their"
#
#
# manchester united lost because their .
# ------------ temperature: 0.5
# -----  Generating with Seed: "air i'd prob eat"
#
#
# air i'd prob eat .
# ------------ temperature: 1.0
# -----  Generating with Seed: "would donate to building the"
#
#
# would donate to building the men their told keep juan the walls .
# ------------ temperature: 1.2
# -----  Generating with Seed: "will absolutely knock him over"
#
#
# will absolutely knock him over tickles air said your ... to the end there and tattoo .Epoch: 3
# Epoch 1/1
# 753882/753882 [==============================] - 2336s - loss: 6.6047
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "there's no evidence that we"
#
#
# there's no evidence that we the .
# ------------ temperature: 0.5
# -----  Generating with Seed: "football you take a mexican"
#
#
# football you take a mexican .
# ------------ temperature: 1.0
# -----  Generating with Seed: "seat sigh and can you"
#
#
# seat sigh and can you less i've order over off year .
# ------------ temperature: 1.2
# -----  Generating with Seed: "being artistic and just"
#
#
# being artistic and just won't car to signs and but u who so guy now you're knows i'd mad side !Epoch: 4
# Epoch 1/1
# 753882/753882 [==============================] - 1473s - loss: 6.3642
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "their i sometimes send"
#
#
# their i sometimes send a .
# ------------ temperature: 0.5
# -----  Generating with Seed: "with drugs ... what does that"
#
#
# with drugs ... what does that just want to have at the .
# ------------ temperature: 1.0
# -----  Generating with Seed: "yoda think 5 is afraid"
#
#
# yoda think 5 is afraid me throw tense ended and first hoes around in the last shit in us guys ?
# ------------ temperature: 1.2
# -----  Generating with Seed: "where he hid the"
#
#
# where he hid the shit and naked will already do you think my company joke was but out bird year my child .Epoch: 5
# Epoch 1/1
# 753882/753882 [==============================] - 1300s - loss: 6.1490
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "you're really fucked up what"
#
#
# you're really fucked up what i was a the other .
# ------------ temperature: 0.5
# -----  Generating with Seed: "bank with finger guns this"
#
#
# bank with finger guns this .
# ------------ temperature: 1.0
# -----  Generating with Seed: "drives me to designated"
#
#
# drives me to designated so .
# ------------ temperature: 1.2
# -----  Generating with Seed: "william shatner i"
#
#
# william shatner i do a phones ?Epoch: 6
# Epoch 1/1
# 753882/753882 [==============================] - 1301s - loss: 6.0607
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "i'll take the girl with"
#
#
# i'll take the girl with the the other .
# ------------ temperature: 0.5
# -----  Generating with Seed: "interest is all"
#
#
# interest is all the phone was .
# ------------ temperature: 1.0
# -----  Generating with Seed: "dog day and women's equality"
#
#
# dog day and women's equality .
# ------------ temperature: 1.2
# -----  Generating with Seed: "wait that's not correction"
#
#
# wait that's not correction in milk is over here relationship means up price learned every name was i'd fuck stand that m a same you is at the bill have one brothers !Epoch: 7
# Epoch 1/1
# 753882/753882 [==============================] - 1304s - loss: 6.0194
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "lentil and a it"
#
#
# lentil and a it .
# ------------ temperature: 0.5
# -----  Generating with Seed: "hopefully it will grow on"
#
#
# hopefully it will grow on the end of the size of the one .
# ------------ temperature: 1.0
# -----  Generating with Seed: "third i would make"
#
#
# third i would make shit at more are half making your swallow to .
# ------------ temperature: 1.2
# -----  Generating with Seed: "they were attached to my"
#
#
# they were attached to my hand an hillary not saying we're late man .Epoch: 8
# Epoch 1/1
# 753882/753882 [==============================] - 1300s - loss: 5.9971
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "luck if he took those"
#
#
# luck if he took those .
# ------------ temperature: 0.5
# -----  Generating with Seed: "11 the remake"
#
#
# 11 the remake .
# ------------ temperature: 1.0
# -----  Generating with Seed: "to the tallest tower in"
#
#
# to the tallest tower in in a son .
# ------------ temperature: 1.2
# -----  Generating with Seed: "hoping that at least one"
#
#
# hoping that at least one in his think they're become amazing my gold now 40 guy thing we put the couch on they're a guy .Epoch: 9
# Epoch 1/1
# 753882/753882 [==============================] - 1305s - loss: 5.9850
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "call a horse who likes"
#
#
# call a horse who likes to be a the the other .
# ------------ temperature: 0.5
# -----  Generating with Seed: "performed a service like wiping"
#
#
# performed a service like wiping to i was a .
# ------------ temperature: 1.0
# -----  Generating with Seed: "fogles favourite vietnamese sum"
#
#
# fogles favourite vietnamese sum are really a he were u sad .
# ------------ temperature: 1.2
# -----  Generating with Seed: "he the steaks were"
#
#
# he the steaks were blood we bus by he got feeling but when it think the guy has no pussy .Epoch: 10
# Epoch 1/1
# 753882/753882 [==============================] - 1301s - loss: 5.9793
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "negative sir it was labeled"
#
#
# negative sir it was labeled a the other .
# ------------ temperature: 0.5
# -----  Generating with Seed: "reach for the preparation h"
#
#
# reach for the preparation h on a lady .
# ------------ temperature: 1.0
# -----  Generating with Seed: "it easy to pick his"
#
#
# it easy to pick his birthday !
# ------------ temperature: 1.2
# -----  Generating with Seed: "sex at which is"
#
#
# sex at which is arrested if you make me him everyone chicken yelling he's gone bartender if it can't always is gets used to always afford them too wasn't fucking ting .Epoch: 11
# Epoch 1/1
# 753882/753882 [==============================] - 1310s - loss: 5.9774
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "wheel the vegtable sitting"
#
#
# wheel the vegtable sitting out of the other .
# ------------ temperature: 0.5
# -----  Generating with Seed: "wow you're a"
#
#
# wow you're a lot of the own one .
# ------------ temperature: 1.0
# -----  Generating with Seed: "ok on 3 lets say what"
#
#
# ok on 3 lets say what in the opposite !
# ------------ temperature: 1.2
# -----  Generating with Seed: "got married soon thereafter they"
#
#
# got married soon thereafter they hate pizza and the bed with his beach .Epoch: 12
# Epoch 1/1
# 753882/753882 [==============================] - 1610s - loss: 5.9738
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "comedian in the"
#
#
# comedian in the shit ?
# ------------ temperature: 0.5
# -----  Generating with Seed: "screaming my life is"
#
#
# screaming my life is a them .
# ------------ temperature: 1.0
# -----  Generating with Seed: "up pick it up pick"
#
#
# up pick it up pick before it sometimes now he is called my shoes ?
# ------------ temperature: 1.2
# -----  Generating with Seed: "i went to 1 once"
#
#
# i went to 1 once i have an abortion .Epoch: 13
# Epoch 1/1
# 753882/753882 [==============================] - 2202s - loss: 5.9743
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "days come get one women"
#
#
# days come get one women .
# ------------ temperature: 0.5
# -----  Generating with Seed: "turns to the other and"
#
#
# turns to the other and says it's a car .
# ------------ temperature: 1.0
# -----  Generating with Seed: "tour de france get"
#
#
# tour de france get out of you sounds is to worry what's a face .
# ------------ temperature: 1.2
# -----  Generating with Seed: "the 1970s it was almost"
#
#
# the 1970s it was almost no in everything .Epoch: 14
# Epoch 1/1
# 753882/753882 [==============================] - 1898s - loss: 5.9759
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "nursing home old guy how"
#
#
# nursing home old guy how like me .
# ------------ temperature: 0.5
# -----  Generating with Seed: "of omeletteyoufinish stolen from"
#
#
# of omeletteyoufinish stolen from a the name of the own them .
# ------------ temperature: 1.0
# -----  Generating with Seed: "check the same three apps"
#
#
# check the same three apps jimmy ran in shoe ?
# ------------ temperature: 1.2
# -----  Generating with Seed: "the word that's changed in"
#
#
# the word that's changed in the fish has there play by attention instead .Epoch: 15
# Epoch 1/1
# 753882/753882 [==============================] - 2696s - loss: 5.9727
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "my coat what's the leading"
#
#
# my coat what's the leading ?
# ------------ temperature: 0.5
# -----  Generating with Seed: "the bank saying i was"
#
#
# the bank saying i was a .
# ------------ temperature: 1.0
# -----  Generating with Seed: "it take sarah palin so"
#
#
# it take sarah palin so google and last night on your your bowl and the wife is stuff in a pizza from front of jesus love i'm gone very bigger then your g money have too than the best and
# ------------ temperature: 1.2
# -----  Generating with Seed: "result is bad i won't"
#
#
# result is bad i won't say joe leaves to stick the when they know you're up or e 50 .Epoch: 16
# Epoch 1/1
# 753882/753882 [==============================] - 3217s - loss: 5.9698
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "do you mean i have"
#
#
# do you mean i have to get a the head .
# ------------ temperature: 0.5
# -----  Generating with Seed: "mark twain used to travel"
#
#
# mark twain used to travel .
# ------------ temperature: 1.0
# -----  Generating with Seed: "found out why they call"
#
#
# found out why they call her to did they did it's 5 in fart ?
# ------------ temperature: 1.2
# -----  Generating with Seed: "how does alabama keep"
#
#
# how does alabama keep excited ?Epoch: 17
# Epoch 1/1
# 753882/753882 [==============================] - 2771s - loss: 5.9682
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "could be a but"
#
#
# could be a but a the other of the the the other .
# ------------ temperature: 0.5
# -----  Generating with Seed: "cute little however i"
#
#
# cute little however i get to the other .
# ------------ temperature: 1.0
# -----  Generating with Seed: "toothpaste to reduce warning"
#
#
# toothpaste to reduce warning from off .
# ------------ temperature: 1.2
# -----  Generating with Seed: "tim cook comes out as"
#
#
# tim cook comes out as because gloves is hot replies i told them up to send by ... yes ... ' thank you .Epoch: 18
# Epoch 1/1
# 753882/753882 [==============================] - 5961s - loss: 5.9700
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "stabbed my friend's butt last"
#
#
# stabbed my friend's butt last night .
# ------------ temperature: 0.5
# -----  Generating with Seed: "gets on 1 knee"
#
#
# gets on 1 knee .
# ------------ temperature: 1.0
# -----  Generating with Seed: "you don't have your florida"
#
#
# you don't have your florida than days ?
# ------------ temperature: 1.2
# -----  Generating with Seed: "old skeleton's dry"
#
#
# old skeleton's dry .Epoch: 19
# Epoch 1/1
# 753882/753882 [==============================] - 13551s - loss: 5.9733
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "into a bartender asks"
#
#
# into a bartender asks i have a the other of the of .
# ------------ temperature: 0.5
# -----  Generating with Seed: "on girls at the bar"
#
#
# on girls at the bar .
# ------------ temperature: 1.0
# -----  Generating with Seed: "wife in bed with a"
#
#
# wife in bed with a up i many twitter .
# ------------ temperature: 1.2
# -----  Generating with Seed: "ass man and fishing isn't"
#
#
# ass man and fishing isn't the flag asking lesson cause her sign goes beef ... i let him talk and what they do skin alive cooler anyway with christmas cake with him until please hide their data mind isn't toldEpoch: 20
# Epoch 1/1
# 753882/753882 [==============================] - 2202s - loss: 5.9782
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "piss off a narcissist just"
#
#
# piss off a narcissist just .
# ------------ temperature: 0.5
# -----  Generating with Seed: "really want to be"
#
#
# really want to be a dog .
# ------------ temperature: 1.0
# -----  Generating with Seed: "the dark no one"
#
#
# the dark no one been gonna .
# ------------ temperature: 1.2
# -----  Generating with Seed: "has sex with many guys"
#
#
# has sex with many guys thread driving round so they work two walk faster .Epoch: 21
# Epoch 1/1
# 753882/753882 [==============================] - 1447s - loss: 5.9809
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "tsss i accidentally ate one"
#
#
# tsss i accidentally ate one .
# ------------ temperature: 0.5
# -----  Generating with Seed: "2 5ths off what is a"
#
#
# 2 5ths off what is a joke ?
# ------------ temperature: 1.0
# -----  Generating with Seed: "is a harware what's"
#
#
# is a harware what's a minute ?
# ------------ temperature: 1.2
# -----  Generating with Seed: "drinking out of a plastic"
#
#
# drinking out of a plastic poo .Epoch: 22
# Epoch 1/1
# 753882/753882 [==============================] - 2005s - loss: 5.9846
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "could screw in one"
#
#
# could screw in one .
# ------------ temperature: 0.5
# -----  Generating with Seed: "and went for a five"
#
#
# and went for a five year of the other .
# ------------ temperature: 1.0
# -----  Generating with Seed: "he dropped his last slice"
#
#
# he dropped his last slice there oh there later so the same style has better ?
# ------------ temperature: 1.2
# -----  Generating with Seed: "what's the best thing"
#
#
# what's the best thing will leave his horse went this places doing the tree king .Epoch: 23
# Epoch 1/1
# 753882/753882 [==============================] - 3640s - loss: 5.9863
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "which country has the maximum"
#
#
# which country has the maximum a other .
# ------------ temperature: 0.5
# -----  Generating with Seed: "a one of them"
#
#
# a one of them is a doctor .
# ------------ temperature: 1.0
# -----  Generating with Seed: "as a result she"
#
#
# as a result she was too a newspaper later you go through the of the other daughter just be in the eyes i wanted to actually be dead very ?
# ------------ temperature: 1.2
# -----  Generating with Seed: "when sounding like a in"
#
#
# when sounding like a in someone cannot be stuck on you is sorry look it's the book around do it's called up first .Epoch: 24
# Epoch 1/1
# 753882/753882 [==============================] - 1425s - loss: 5.9892
#
#
#
# ------------ temperature: 0.2
# -----  Generating with Seed: "the difference between a snowman"
#
#
# the difference between a snowman .
# ------------ temperature: 0.5
# -----  Generating with Seed: "is green and has wheels"
#
#
# is green and has wheels .
# ------------ temperature: 1.0
# -----  Generating with Seed: "it and she couldn't figure"
#
#
# it and she couldn't figure out about standing to a a his think tickles to games .
# ------------ temperature: 1.2
# -----  Generating with Seed: "i'm good on running for"
#
#
# i'm good on running for the little suicide now and tomorrow yet room fan while with pants out of the other i'm ever won he is sorry who man do i runs on ?Epoch: 25
# Epoch 1/1
# 726796/753882 [===========================>..] - ETA: 58s - loss: 5.9941
